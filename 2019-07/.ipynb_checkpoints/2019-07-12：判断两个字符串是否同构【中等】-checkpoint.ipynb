# %% [markdown]
# # 字符串按照单词反转【简单】

# %% [markdown]
# 将字符串按照单词翻转。
#
# 例如：输入s = "Python love I"
# 输出为 "I love Python"

# %%
#==============================答题区==============================#




















#==============================答题区==============================#

# %%
#==============================提示区==============================#




































































#  提示：字符串常用函数split,join,reverse
































































































































#==============================提示区==============================#

# %%
#==============================答案区==============================#
# 解题思路：先以空格分隔为列表，reverse后用空格join

s = "Python Love I"

def f(s):
    result = " ".join(s.split(" ")[])
    return(result)
f(s)
#==============================答案区==============================#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2c282a26a1c5> in <module>
#       7     result = " ".join(s.split(" ").reverse())
#       8     return(result)
# ----> 9 f(s)
#      10 #==============================答案区==============================#
#
# <ipython-input-1-2c282a26a1c5> in f(s)
#       5
#       6 def f(s):
# ----> 7     result = " ".join(s.split(" ").reverse())
#       8     return(result)
#       9 f(s)
#
# TypeError: can only join an iterable

# %% [markdown]
# ![](../Python与算法之美.jpg)
