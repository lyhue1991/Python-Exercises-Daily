# %% [markdown]
# # 数字三角形【困难】

# %% [markdown]
#  在下面的数字三角形中寻找一条从顶部到底边的路径，使得路径上所经过的数字之和最大。
#  路径上的每一步都只能往左下或 右下走。只需要求出这个最大和即可，不必给出具体路径。

# %%
arr = [[7],[3,8],[8,1,0],[2,7,4,4],[4,5,2,6,5]]
for x in arr:
    print(("{:^10}").format(' '.join([str(i) for i in x])))
# Out:
#     7
#    3 8
#   8 1 0
#  2 7 4 4
# 4 5 2 6 5

# %%
#==============================答题区==============================#




















#==============================答题区==============================#

# %%
#==============================提示区==============================#




































































#  提示：动态规划算法
































































































































#==============================提示区==============================#

# %%
#==============================答案区==============================#
# 解题思路：动态规划算法
# 到达arr[i][j]位置时的最大可能累积和满足如下递推关系
# maxsum[i][j] = max(maxsum[i-1][j],maxsum[i-1][j])+arr[i][j]

arr = [[7],[3,8],[8,1,0],[2,7,4,4],[4,5,2,6,5]]

def f(arr):
    maxsum = arr[0]
    if len(arr)==1:
        return(maxsum[0])
    for x in arr[1:]:
        first = maxsum[0] + x[0]
        last = maxsum[-1] + x[-1]
        maxsum = [first] + \
        [max(maxsum[j-1],maxsum[j])+x[j] for j in range(1,len(x)-1)]+\
        [last]
    return(max(maxsum))
    
f(arr)

#==============================答案区==============================#
# Out:
# 30

# %% [markdown]
# ![](../Python与算法之美.jpg)
